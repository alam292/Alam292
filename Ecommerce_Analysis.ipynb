# %% [markdown]
# <a href="https://colab.research.google.com/github/alam292/Alam292/blob/main/Ecommerce_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Data Collection

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f0046f0-0168-4383-a741-bb0199e542f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f0046f0-0168-4383-a741-bb0199e542f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("orders.csv")

# %%
df
# Out:
#            order_id customer_id   product_id  seller_id  \
# 0       ORD00000001  CUST030578  PROD0006320  SELL01114
# 1       ORD00000002  CUST008134  PROD0006694  SELL00275
# 2       ORD00000003  CUST018918  PROD0007508  SELL00674
# 3       ORD00000004  CUST019490  PROD0001008  SELL00423
# 4       ORD00000005  CUST009380  PROD0005506  SELL01230
# ...             ...         ...          ...        ...
# 379495  ORD00379496  CUST031314  PROD0002966  SELL01536
# 379496  ORD00379497  CUST017554  PROD0000052  SELL00877
# 379497  ORD00379498  CUST004270  PROD0005308  SELL00104
# 379498  ORD00379499  CUST014634  PROD0004705  SELL00968
# 379499  ORD00379500  CUST018208  PROD0000765  SELL00764
#
#                         order_date order_status  quantity  unit_price  \
# 0       2026-01-03 11:53:24.443541    delivered         3     6119.38
# 1       2026-01-03 11:54:24.443541    DELIVERED         8     1091.73
# 2       2026-01-03 11:55:24.443541    Delivered         9     2241.77
# ...

# %% [markdown]
# ##Data Understanding

# %%
df.head()
# Out:
#       order_id customer_id   product_id  seller_id  \
# 0  ORD00000001  CUST030578  PROD0006320  SELL01114
# 1  ORD00000002  CUST008134  PROD0006694  SELL00275
# 2  ORD00000003  CUST018918  PROD0007508  SELL00674
# 3  ORD00000004  CUST019490  PROD0001008  SELL00423
# 4  ORD00000005  CUST009380  PROD0005506  SELL01230
#
#                    order_date order_status  quantity  unit_price  discount  \
# 0  2026-01-03 11:53:24.443541    delivered         3     6119.38     44.14
# 1  2026-01-03 11:54:24.443541    DELIVERED         8     1091.73     17.08
# 2  2026-01-03 11:55:24.443541    Delivered         9     2241.77     49.01
# 3  2026-01-03 11:56:24.443541      shipped         5     2509.03      5.25
# 4  2026-01-03 11:57:24.443541    delivered         6     8852.91     46.81
#
#    tax_amount  shipping_fee  total_amount   payment_id payment_method  \
# 0     1162.17        197.02      24035.61  PAY00120243            COD
# ...
